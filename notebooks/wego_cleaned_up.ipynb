# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.cm import PRGn
import seaborn as sns
import calendar
from datetime import date
from datetime import datetime
plt.style.use('ggplot')

# %%
headway = pd.read_csv("../data/Headway_Data.csv", nrows=1981716)

# %%
pd.set_option('display.max_columns', None)

# %%
headway.head(4)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# 2        1704      2088   297750            0          TO DOWNTOWN
# 3        1704      2088   297749            0          TO DOWNTOWN
#
#   TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 0            HBHS                  4.0          1  36.107575 -86.812719
# 1            21BK                  3.0          0  36.138372 -86.800622
# 2          MCC5_9                  2.0          2  36.167091 -86.781923
# 3            MLKS                  7.0          1  36.161008 -86.800851
#
#   SCHEDULED_TIME ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  \
# 0     14:10:00            13:59:21              14:12:00    -2.000000
# 1     14:20:00            14:23:21              14:23:21    -3.350000
# 2     14:39:00            14:36:46              14:59:11   -20.183333
# 3     15:10:00            15:04:31              15:10:17    -0.283333
#
#    SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  \
# 0            14.0    15.983333  1.983333                     0
# 1            14.0    17.333333  3.333333                     0
# 2             NaN          NaN       NaN                     0
# 3             NaN          NaN       NaN                     0
#
#    ADJUSTED_LATE_COUNT  ADJUSTED_ONTIME_COUNT  STOP_CANCELLED  \
# 0                    0                      1               0
# 1                    0                      1               0
# 2                    1                      0               0
# 3                    0                      1               0
#
#    PREV_SCHED_STOP_CANCELLED  IS_RELIEF  BLOCK_STOP_ORDER  DWELL_IN_MINS
# 0                        0.0          0                 2      12.650000
# 1                        0.0          0                11       0.000000
# 2                        NaN          0                23      22.416666
# 3                        0.0          0                24       5.766666

# %%
headway.drop(headway.columns[[-1,-2, -3, -4, -5, -6, -7, -8]], axis = 1, inplace=True)

# %%
headway.head(3)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# 2        1704      2088   297750            0          TO DOWNTOWN
#
#   TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 0            HBHS                  4.0          1  36.107575 -86.812719
# 1            21BK                  3.0          0  36.138372 -86.800622
# 2          MCC5_9                  2.0          2  36.167091 -86.781923
#
#   SCHEDULED_TIME ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  \
# 0     14:10:00            13:59:21              14:12:00    -2.000000
# 1     14:20:00            14:23:21              14:23:21    -3.350000
# 2     14:39:00            14:36:46              14:59:11   -20.183333
#
#    SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV
# 0            14.0    15.983333  1.983333
# 1            14.0    17.333333  3.333333
# 2             NaN          NaN       NaN

# %%
headway['DATE'] =  pd.to_datetime(headway['DATE'])

# %%
headway['WEEKDAY'] = [calendar.day_name[x.weekday()] for x in headway['DATE']]
headway.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  BLOCK_ABBR  \
# 0    120211101             1      76447164 2021-11-01           7        1704
# 1    120211101             1      76447165 2021-11-01           7        1704
# 2    120211101             1      76447166 2021-11-01           7        1704
# 3    120211101             1      76447167 2021-11-01          50        1704
# 4    120211101             1      76447168 2021-11-01          50        1704
#
#    OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME TIME_POINT_ABBR  \
# 0      2088   297750            0          TO DOWNTOWN            HBHS
# 1      2088   297750            0          TO DOWNTOWN            21BK
# 2      2088   297750            0          TO DOWNTOWN          MCC5_9
# 3      2088   297749            0          TO DOWNTOWN            MLKS
# 4      2088   297749            0          TO DOWNTOWN         MCC5_11
#
#    ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE SCHEDULED_TIME  \
# 0                  4.0          1  36.107575 -86.812719     14:10:00
# 1                  3.0          0  36.138372 -86.800622     14:20:00
# 2                  2.0          2  36.167091 -86.781923     14:39:00
# 3                  7.0          1  36.161008 -86.800851     15:10:00
# 4                  5.0          2  36.167091 -86.781923     15:27:00
#
#   ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  SCHEDULED_HDWY  \
# 0          13:59:21              14:12:00    -2.000000            14.0
# 1          14:23:21              14:23:21    -3.350000            14.0
# 2          14:36:46              14:59:11   -20.183333             NaN
# 3          15:04:31              15:10:17    -0.283333             NaN
# 4          15:16:59              15:16:59    10.016666             NaN
#
#    ACTUAL_HDWY  HDWY_DEV WEEKDAY
# 0    15.983333  1.983333  Monday
# 1    17.333333  3.333333  Monday
# 2          NaN       NaN  Monday
# 3          NaN       NaN  Monday
# 4          NaN       NaN  Monday

# %%
DOW = headway[['WEEKDAY','SCHEDULED_HDWY', 'ACTUAL_HDWY','ADHERENCE', 'ROUTE_ABBR']]

# %%
(DOW.pivot_table(
        index='WEEKDAY',
    columns= 'ROUTE_ABBR',
    values='ADHERENCE',
    aggfunc= 'median').style.background_gradient(cmap='Purples', axis=1))
# Out:
# <style type="text/css">
# #T_014e3_row0_col0 {
#   background-color: #9c98c7;
#   color: #f1f1f1;
# }
# #T_014e3_row0_col1, #T_014e3_row6_col1 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_014e3_row0_col2, #T_014e3_row0_col3, #T_014e3_row1_col3, #T_014e3_row2_col2, #T_014e3_row3_col1, #T_014e3_row4_col2, #T_014e3_row5_col2, #T_014e3_row6_col2, #T_014e3_row6_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_014e3_row0_col4 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_014e3_row0_col5 {
#   background-color: #8380bb;
#   color: #f1f1f1;
# }
# #T_014e3_row0_col6, #T_014e3_row1_col6, #T_014e3_row2_col6, #T_014e3_row3_col6, #T_014e3_row4_col6, #T_014e3_row5_col6, #T_014e3_row6_col6 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_014e3_row0_col7, #T_014e3_row2_col4 {
#   background-color: #776ab0;
#   color: #f1f1f1;
# }
# #T_014e3_row1_col0 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_014e3_row1_col1 {
#   background-color: #a3a0cb;
#   color: #f1f1f1;
# }
# #T_014e3_row1_col2 {
#   background-color: #5a3294;
#   color: #f1f1f1;
# }
# #T_014e3_row1_col4 {
#   background-color: #dedded;
#   color: #000000;
# }
# #T_014e3_row1_col5 {
#   background-color: #4e1c8a;
#   color: #f1f1f1;
# }
# #T_014e3_row1_col7 {
#   background-color: #7261ab;
#   color: #f1f1f1;
# }
# #T_014e3_row2_col0 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_014e3_row2_col1 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_014e3_row2_col3 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_014e3_row2_col5 {
#   background-color: #7465ad;
#   color: #f1f1f1;
# }
# #T_014e3_row2_col7 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_014e3_row3_col0 {
#   background-color: #dfdfed;
#   color: #000000;
# }
# #T_014e3_row3_col2 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_014e3_row3_col3 {
#   background-color: #593093;
#   color: #f1f1f1;
# }
# #T_014e3_row3_col4 {
#   background-color: #8c88bf;
#   color: #f1f1f1;
# }
# #T_014e3_row3_col5 {
#   background-color: #6d57a6;
#   color: #f1f1f1;
# }
# #T_014e3_row3_col7 {
#   background-color: #61409b;
#   color: #f1f1f1;
# }
# #T_014e3_row4_col0 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_014e3_row4_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_014e3_row4_col3 {
#   background-color: #582e92;
#   color: #f1f1f1;
# }
# #T_014e3_row4_col4 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_014e3_row4_col5, #T_014e3_row4_col7 {
#   background-color: #6950a3;
#   color: #f1f1f1;
# }
# #T_014e3_row5_col0, #T_014e3_row5_col4, #T_014e3_row6_col4 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_014e3_row5_col1 {
#   background-color: #cecee5;
#   color: #000000;
# }
# #T_014e3_row5_col3 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_014e3_row5_col5 {
#   background-color: #562b91;
#   color: #f1f1f1;
# }
# #T_014e3_row5_col7 {
#   background-color: #5e3b98;
#   color: #f1f1f1;
# }
# #T_014e3_row6_col0 {
#   background-color: #eae8f2;
#   color: #000000;
# }
# #T_014e3_row6_col5 {
#   background-color: #7669af;
#   color: #f1f1f1;
# }
# #T_014e3_row6_col7 {
#   background-color: #7a71b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_014e3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >ROUTE_ABBR</th>
#       <th id="T_014e3_level0_col0" class="col_heading level0 col0" >3</th>
#       <th id="T_014e3_level0_col1" class="col_heading level0 col1" >7</th>
#       <th id="T_014e3_level0_col2" class="col_heading level0 col2" >22</th>
#       <th id="T_014e3_level0_col3" class="col_heading level0 col3" >23</th>
#       <th id="T_014e3_level0_col4" class="col_heading level0 col4" >50</th>
#       <th id="T_014e3_level0_col5" class="col_heading level0 col5" >52</th>
#       <th id="T_014e3_level0_col6" class="col_heading level0 col6" >55</th>
#       <th id="T_014e3_level0_col7" class="col_heading level0 col7" >56</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >WEEKDAY</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_014e3_level0_row0" class="row_heading level0 row0" >Friday</th>
#       <td id="T_014e3_row0_col0" class="data row0 col0" >-1.600000</td>
#       <td id="T_014e3_row0_col1" class="data row0 col1" >-1.833333</td>
#       <td id="T_014e3_row0_col2" class="data row0 col2" >-1.116666</td>
#       <td id="T_014e3_row0_col3" class="data row0 col3" >-1.116666</td>
#       <td id="T_014e3_row0_col4" class="data row0 col4" >-1.783333</td>
#       <td id="T_014e3_row0_col5" class="data row0 col5" >-1.500000</td>
#       <td id="T_014e3_row0_col6" class="data row0 col6" >-2.100000</td>
#       <td id="T_014e3_row0_col7" class="data row0 col7" >-1.433333</td>
#     </tr>
#     <tr>
#       <th id="T_014e3_level0_row1" class="row_heading level0 row1" >Monday</th>
#       <td id="T_014e3_row1_col0" class="data row1 col0" >-1.433333</td>
#       <td id="T_014e3_row1_col1" class="data row1 col1" >-1.266666</td>
#       <td id="T_014e3_row1_col2" class="data row1 col2" >-1.000000</td>
#       <td id="T_014e3_row1_col3" class="data row1 col3" >-0.883333</td>
#       <td id="T_014e3_row1_col4" class="data row1 col4" >-1.450000</td>
#       <td id="T_014e3_row1_col5" class="data row1 col5" >-0.950000</td>
#       <td id="T_014e3_row1_col6" class="data row1 col6" >-1.616666</td>
#       <td id="T_014e3_row1_col7" class="data row1 col7" >-1.100000</td>
#     </tr>
#     <tr>
#       <th id="T_014e3_level0_row2" class="row_heading level0 row2" >Saturday</th>
#       <td id="T_014e3_row2_col0" class="data row2 col0" >-2.000000</td>
#       <td id="T_014e3_row2_col1" class="data row2 col1" >-1.983333</td>
#       <td id="T_014e3_row2_col2" class="data row2 col2" >-1.116666</td>
#       <td id="T_014e3_row2_col3" class="data row2 col3" >-1.350000</td>
#       <td id="T_014e3_row2_col4" class="data row2 col4" >-1.433333</td>
#       <td id="T_014e3_row2_col5" class="data row2 col5" >-1.416666</td>
#       <td id="T_014e3_row2_col6" class="data row2 col6" >-2.100000</td>
#       <td id="T_014e3_row2_col7" class="data row2 col7" >-1.666666</td>
#     </tr>
#     <tr>
#       <th id="T_014e3_level0_row3" class="row_heading level0 row3" >Sunday</th>
#       <td id="T_014e3_row3_col0" class="data row3 col0" >-1.450000</td>
#       <td id="T_014e3_row3_col1" class="data row3 col1" >-0.866666</td>
#       <td id="T_014e3_row3_col2" class="data row3 col2" >-1.050000</td>
#       <td id="T_014e3_row3_col3" class="data row3 col3" >-0.983333</td>
#       <td id="T_014e3_row3_col4" class="data row3 col4" >-1.183333</td>
#       <td id="T_014e3_row3_col5" class="data row3 col5" >-1.066666</td>
#       <td id="T_014e3_row3_col6" class="data row3 col6" >-1.616666</td>
#       <td id="T_014e3_row3_col7" class="data row3 col7" >-1.016666</td>
#     </tr>
#     <tr>
#       <th id="T_014e3_level0_row4" class="row_heading level0 row4" >Thursday</th>
#       <td id="T_014e3_row4_col0" class="data row4 col0" >-1.633333</td>
#       <td id="T_014e3_row4_col1" class="data row4 col1" >-1.550000</td>
#       <td id="T_014e3_row4_col2" class="data row4 col2" >-0.983333</td>
#       <td id="T_014e3_row4_col3" class="data row4 col3" >-1.100000</td>
#       <td id="T_014e3_row4_col4" class="data row4 col4" >-1.666666</td>
#       <td id="T_014e3_row4_col5" class="data row4 col5" >-1.183333</td>
#       <td id="T_014e3_row4_col6" class="data row4 col6" >-1.783333</td>
#       <td id="T_014e3_row4_col7" class="data row4 col7" >-1.183333</td>
#     </tr>
#     <tr>
#       <th id="T_014e3_level0_row5" class="row_heading level0 row5" >Tuesday</th>
#       <td id="T_014e3_row5_col0" class="data row5 col0" >-1.666666</td>
#       <td id="T_014e3_row5_col1" class="data row5 col1" >-1.516666</td>
#       <td id="T_014e3_row5_col2" class="data row5 col2" >-1.016666</td>
#       <td id="T_014e3_row5_col3" class="data row5 col3" >-1.033333</td>
#       <td id="T_014e3_row5_col4" class="data row5 col4" >-1.666666</td>
#       <td id="T_014e3_row5_col5"

# %%
from pivottablejs import pivot_ui

# %% [markdown]
# # passes data to a chart pivot style
# a= [ [1,'Requirements','bug'],[2,'Design','bug'],[3,'Testing','bug'],[4,'Requirements','bug'],[5,'Requirements','Inquiry'] ]
#
# df  = pd.DataFrame(a,columns =['Issue#','OriginationPhase','Category'])
#
# pivot_ui(df)

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
headway_holiday = headway[headway["DATE"].isin(['2021-11-11', '2021-11-25', '2021-12-24', '2021-12-31',
               '2022-01-17', '2022-02-21', '2022-05-30', '2022-06-20',
               '2022-07-04', '2022-09-05', '2022-10-10'])]

# %%
headway_holiday.head(10)
# Out:
#        CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  \
# 53790    120211111             1      76887104 2021-11-11          22
# 53791    120211111             1      76887105 2021-11-11          22
# 53792    120211111             1      76887106 2021-11-11          22
# 53793    120211111             1      76887107 2021-11-11          22
# 53794    120211111             1      76887108 2021-11-11          22
# 53795    120211111             1      76887109 2021-11-11          22
# 53796    120211111             1      76887110 2021-11-11          22
# 53797    120211111             1      76887111 2021-11-11          22
# 53798    120211111             1      76887112 2021-11-11          22
# 53799    120211111             1      76887113 2021-11-11          22
#
#        BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 53790        2200      1796   298143            0          TO DOWNTOWN
# 53791        2200      1796   298143            0          TO DOWNTOWN
# 53792        2200      1796   298143            0          TO DOWNTOWN
# 53793        2200      1796   298143            0          TO DOWNTOWN
# 53794        2200      1796   298162            0        FROM DOWNTOWN
# 53795        2200      1796   298162            0        FROM DOWNTOWN
# 53796        2200      1796   298162            0        FROM DOWNTOWN
# 53797        2200      1796   298128            0          TO DOWNTOWN
# 53798        2200      1796   298128            0          TO DOWNTOWN
# 53799        2200      1796   298128            0          TO DOWNTOWN
#
#       TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 53790            MHSP                 15.0          1  36.178360 -86.845441
# 53791            ELIZ                 11.0          0  36.193454 -86.839981
# 53792            CV23                  6.0          0  36.182177 -86.814445
# 53793         MCC5_12                  4.0          2  36.167091 -86.781923
# 53794         MCC5_12                  4.0          1  36.167091 -86.781923
# 53795            CV23                  6.0          0  36.183480 -86.814220
# 53796            MHSP                 15.0          2  36.178360 -86.845441
# 53797            MHSP                 15.0          1  36.178360 -86.845441
# 53798            ELIZ                 11.0          0  36.193454 -86.839981
# 53799            CV23                  6.0          0  36.182177 -86.814445
#
#       SCHEDULED_TIME ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  \
# 53790     04:42:00            04:38:54              04:41:02     0.966666
# 53791     04:46:00            04:47:47              04:47:47    -1.783333
# 53792     04:54:00            04:54:14              04:54:14    -0.233333
# 53793     05:10:00            05:03:41              05:03:41     6.316666
# 53794     05:15:00            05:03:41              05:19:21    -4.350000
# 53795     05:25:00            05:27:39              05:27:39    -2.650000
# 53796     05:32:00            05:35:34              05:35:34    -3.566666
# 53797     05:42:00            05:35:34              05:41:03     0.950000
# 53798     05:46:00            05:47:44              05:47:44    -1.733333
# 53799     05:54:00            05:55:48              05:55:48    -1.800000
#
#        SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV   WEEKDAY
# 53790             NaN          NaN       NaN  Thursday
# 53791             NaN          NaN       NaN  Thursday
# 53792             NaN          NaN       NaN  Thursday
# 53793             NaN          NaN       NaN  Thursday
# 53794             NaN          NaN       NaN  Thursday
# 53795             NaN          NaN       NaN  Thursday
# 53796             NaN          NaN       NaN  Thursday
# 53797            35.0    33.316666 -1.683334  Thursday
# 53798            35.0    35.850000  0.850000  Thursday
# 53799            15.0    17.416666  2.416666  Thursday

# %% [markdown]
# RUSH_HOUR = []
#
# for x in hw_clean['SCHEDULED_TIME']:
#     if x >= '07:00:00' and x <= '09:30:00':
#         RUSH_HOUR.append('Morning Rush')
#     elif x >= '16:00:00' and x <= '18:00:00':
#         RUSH_HOUR.append('Evening Rush')
#     else:
#         RUSH_HOUR.append('No Rush')
# RUSH_HOUR

# %%
#| works as an or operator 
summer = headway[(headway["DATE"] >= '2022-06-01') & (headway["DATE"] <= '2022-08-01')]
#headway['DATE'] > '2022-06-01') & (headway['DATE'] <= '2022-08-01')])]

# %%
summer['DATE']
# Out:
# 1109085   2022-06-01
# 1109086   2022-06-01
# 1109087   2022-06-01
# 1109088   2022-06-01
# 1109089   2022-06-01
#              ...
# 1458067   2022-08-01
# 1458068   2022-08-01
# 1458069   2022-08-01
# 1458070   2022-08-01
# 1458071   2022-08-01
# Name: DATE, Length: 348987, dtype: datetime64[ns]

# %% [markdown]
# #create a df with start and end dates
#
# start_date = '2022-06-01' ##define start date
# end_date = '2022-08-01' ##define end date
#
# after_start_date = headway["DATE"] >= start_date ##create sub df for all dates >= start date
# before_end_date = headway["DATE"] <= end_date ##create sub df for all dates <= end date
#
# between_two_dates = after_start_date & before_end_date ##combine sub dfs into another sub df
#
# df2 = headway.loc[between_two_dates] ##use .loc on main df referencing all the dates within the between sub df
# df2

# %%
summer.head(10)
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  \
# 1109085    120220601             1      85713482 2022-06-01          22
# 1109086    120220601             1      85713483 2022-06-01          22
# 1109087    120220601             1      85713484 2022-06-01          22
# 1109088    120220601             1      85713485 2022-06-01          22
# 1109089    120220601             1      85713486 2022-06-01          22
# 1109090    120220601             1      85713487 2022-06-01          22
# 1109091    120220601             1      85713488 2022-06-01          22
# 1109092    120220601             1      85713489 2022-06-01          22
# 1109093    120220601             1      85713490 2022-06-01          22
# 1109094    120220601             1      85713491 2022-06-01          22
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 1109085        2200      1280   311622            0          TO DOWNTOWN
# 1109086        2200      1280   311622            0          TO DOWNTOWN
# 1109087        2200      1280   311622            0          TO DOWNTOWN
# 1109088        2200      1280   311622            0          TO DOWNTOWN
# 1109089        2200      1280   311641            0        FROM DOWNTOWN
# 1109090        2200      1280   311641            0        FROM DOWNTOWN
# 1109091        2200      1280   311641            0        FROM DOWNTOWN
# 1109092        2200      1280   311607            0          TO DOWNTOWN
# 1109093        2200      1280   311607            0          TO DOWNTOWN
# 1109094        2200      1280   311607            0          TO DOWNTOWN
#
#         TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 1109085            MHSP                 14.0          1  36.178360 -86.845441
# 1109086            ELIZ                 10.0          0  36.193454 -86.839981
# 1109087            CV23                  5.0          0  36.182177 -86.814445
# 1109088         MCC5_10                  1.0          2  36.167091 -86.781923
# 1109089         MCC5_10                  1.0          1  36.167091 -86.781923
# 1109090            CV23                  5.0          0  36.183480 -86.814220
# 1109091            MHSP                 14.0          2  36.178360 -86.845441
# 1109092            MHSP                 14.0          1  36.178360 -86.845441
# 1109093            ELIZ                 10.0          0  36.193454 -86.839981
# 1109094            CV23                  5.0          0  36.182177 -86.814445
#
#         SCHEDULED_TIME ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  \
# 1109085     04:42:00            04:26:03              04:41:02     0.966666
# 1109086     04:46:00            04:45:38              04:45:38     0.366666
# 1109087     04:54:00            04:53:16              04:53:16     0.733333
# 1109088     05:10:00            04:59:40              04:59:40    10.333333
# 1109089     05:15:00            04:59:40              05:17:15    -2.250000
# 1109090     05:25:00            05:24:06              05:24:06     0.900000
# 1109091     05:32:00            05:31:04              05:31:04     0.933333
# 1109092     05:42:00            05:31:04              05:41:02     0.966666
# 1109093     05:46:00            05:46:32              05:46:32    -0.533333
# 1109094     05:54:00            05:53:48              05:53:48     0.200000
#
#          SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV    WEEKDAY
# 1109085             NaN          NaN       NaN  Wednesday
# 1109086             NaN          NaN       NaN  Wednesday
# 1109087             NaN          NaN       NaN  Wednesday
# 1109088             NaN          NaN       NaN  Wednesday
# 1109089             NaN          NaN       NaN  Wednesday
# 1109090             NaN          NaN       NaN  Wednesday
# 1109091             NaN          NaN       NaN  Wednesday
# 1109092            35.0    32.116666 -2.883334  Wednesday
# 1109093            35.0    33.500000 -1.500000  Wednesday
# 1109094            15.0    15.250000  0.250000  Wednesday

# %% [markdown]
# ##chart to compare adherence per day
#
# early = pd.DataFrame({'x':['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
#                        'y':[71324, 70162, 66838, 65762, 61969, 39433, 39666]})
# late = pd.DataFrame({'x':['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
#                          'y':[239369, 251037, 243731, 241403, 243201, 153800, 132869]})
# ontime = pd.DataFrame({'x':['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
#                           'y':[8118, 7960, 12465, 12087, 9848, 6157, 4516]})
#
# early['Adherence']='Early'
# late['Adherence']='Late'
# ontime['Adherence']='On Time'
# res=pd.concat([early, late, ontime])
# sns.set_style('whitegrid')
# fig, ax = plt.subplots(figsize=(8,6))
# sns.barplot(x='x',y='y',data=res,hue='Adherence', palette='Paired', ax=ax)
# plt.xlabel('Day of Week')
# plt.ylabel('Count')
# plt.ylim(0, 260000)
# plt.title('Adherence by Day of Week')
# plt.savefig('adh-by-dow.png')
# plt.show()

# %% [markdown]
# ##get count of on time perf per day
#
# mon = hw_clean.loc[hw_clean['WEEKDAY']=='Monday']
# tue = hw_clean.loc[hw_clean['WEEKDAY']=='Tuesday']
# wed = hw_clean.loc[hw_clean['WEEKDAY']=='Wednesday']
# thu = hw_clean.loc[hw_clean['WEEKDAY']=='Thursday']
# fri = hw_clean.loc[hw_clean['WEEKDAY']=='Friday']
# sat = hw_clean.loc[hw_clean['WEEKDAY']=='Saturday']
# sun = hw_clean.loc[hw_clean['WEEKDAY']=='Sunday']
#
# print('monday')
# print(mon['ON_TIME_PERF'].value_counts())
# print('')
# print('tueday')
# print(tue['ON_TIME_PERF'].value_counts())
# print('')
# print('wednesday')
# print(wed['ON_TIME_PERF'].value_counts())
# print('')
# print('thursday')
# print(thu['ON_TIME_PERF'].value_counts())
# print('')
# print('friday')
# print(fri['ON_TIME_PERF'].value_counts())
# print('')
# print('saturday')
# print(sat['ON_TIME_PERF'].value_counts())
# print('')
# print('sunday')
# print(sun['ON_TIME_PERF'].value_counts())
# print('')

# %% [markdown]
# RUSH_HOUR = []
#
# for x in hw_clean['SCHEDULED_TIME']:
#     if x >= '07:00:00' and x <= '09:30:00':
#         RUSH_HOUR.append('Morning Rush')
#     elif x >= '16:00:00' and x <= '18:00:00':
#         RUSH_HOUR.append('Evening Rush')
#     else:
#         RUSH_HOUR.append('No Rush')
# RUSH_HOUR

# %%
summer.head(1)
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  \
# 1109085    120220601             1      85713482 2022-06-01          22
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 1109085        2200      1280   311622            0          TO DOWNTOWN
#
#         TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE  LATITUDE  LONGITUDE  \
# 1109085            MHSP                 14.0          1  36.17836 -86.845441
#
#         SCHEDULED_TIME ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  \
# 1109085     04:42:00            04:26:03              04:41:02     0.966666
#
#          SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV    WEEKDAY
# 1109085             NaN          NaN       NaN  Wednesday

# %%
##initialize empty list to fill with results
ON_TIME_PERF = []

##loop to check adherence column to determine if early, late, or on time append

for x in summer['ADHERENCE']:
    if x > 0:
        ON_TIME_PERF.append('EARLY')
    elif x < 0:
        ON_TIME_PERF.append('LATE')
    else:
        ON_TIME_PERF.append('ON TIME')

# %%
len(ON_TIME_PERF)
# Out:
# 348987

# %%
summer['Time']  = ON_TIME_PERF

##add to main df by concat function
#summer = pd.concat([summer, summer_ot], axis='columns')
#summer
# Out:
# C:\Users\cside\AppData\Local\Temp\ipykernel_11932\658406962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer['Time']  = ON_TIME_PERF

# %%
summer.shape
# Out:
# (348987, 24)

# %%
summer.head(10)
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  \
# 1109085    120220601             1      85713482 2022-06-01          22
# 1109086    120220601             1      85713483 2022-06-01          22
# 1109087    120220601             1      85713484 2022-06-01          22
# 1109088    120220601             1      85713485 2022-06-01          22
# 1109089    120220601             1      85713486 2022-06-01          22
# 1109090    120220601             1      85713487 2022-06-01          22
# 1109091    120220601             1      85713488 2022-06-01          22
# 1109092    120220601             1      85713489 2022-06-01          22
# 1109093    120220601             1      85713490 2022-06-01          22
# 1109094    120220601             1      85713491 2022-06-01          22
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 1109085        2200      1280   311622            0          TO DOWNTOWN
# 1109086        2200      1280   311622            0          TO DOWNTOWN
# 1109087        2200      1280   311622            0          TO DOWNTOWN
# 1109088        2200      1280   311622            0          TO DOWNTOWN
# 1109089        2200      1280   311641            0        FROM DOWNTOWN
# 1109090        2200      1280   311641            0        FROM DOWNTOWN
# 1109091        2200      1280   311641            0        FROM DOWNTOWN
# 1109092        2200      1280   311607            0          TO DOWNTOWN
# 1109093        2200      1280   311607            0          TO DOWNTOWN
# 1109094        2200      1280   311607            0          TO DOWNTOWN
#
#         TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 1109085            MHSP                 14.0          1  36.178360 -86.845441
# 1109086            ELIZ                 10.0          0  36.193454 -86.839981
# 1109087            CV23                  5.0          0  36.182177 -86.814445
# 1109088         MCC5_10                  1.0          2  36.167091 -86.781923
# 1109089         MCC5_10                  1.0          1  36.167091 -86.781923
# 1109090            CV23                  5.0          0  36.183480 -86.814220
# 1109091            MHSP                 14.0          2  36.178360 -86.845441
# 1109092            MHSP                 14.0          1  36.178360 -86.845441
# 1109093            ELIZ                 10.0          0  36.193454 -86.839981
# 1109094            CV23                  5.0          0  36.182177 -86.814445
#
#         SCHEDULED_TIME ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  \
# 1109085     04:42:00            04:26:03              04:41:02     0.966666
# 1109086     04:46:00            04:45:38              04:45:38     0.366666
# 1109087     04:54:00            04:53:16              04:53:16     0.733333
# 1109088     05:10:00            04:59:40              04:59:40    10.333333
# 1109089     05:15:00            04:59:40              05:17:15    -2.250000
# 1109090     05:25:00            05:24:06              05:24:06     0.900000
# 1109091     05:32:00            05:31:04              05:31:04     0.933333
# 1109092     05:42:00            05:31:04              05:41:02     0.966666
# 1109093     05:46:00            05:46:32              05:46:32    -0.533333
# 1109094     05:54:00            05:53:48              05:53:48     0.200000
#
#          SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV    WEEKDAY   Time
# 1109085             NaN          NaN       NaN  Wednesday  EARLY
# 1109086             NaN          NaN       NaN  Wednesday  EARLY
# 1109087             NaN          NaN       NaN  Wednesday  EARLY
# 1109088             NaN          NaN       NaN  Wednesday  EARLY
# 1109089             NaN          NaN       NaN  Wednesday   LATE
# 1109090             NaN          NaN       NaN  Wednesday  EARLY
# 1109091             NaN          NaN       NaN  Wednesday  EARLY
# 1109092            35.0    32.116666 -2.883334  Wednesday  EARLY
# 1109093            35.0    33.500000 -1.500000  Wednesday   LATE
# 1109094            15.0    15.250000  0.250000  Wednesday  EARLY

# %%
(summer.pivot_table(
        index='WEEKDAY',
    columns= 'Time',
    values='ADHERENCE',
    aggfunc= 'mean').style.background_gradient(cmap='Purples', axis=1))
# Out:
# <style type="text/css">
# #T_0ab20_row0_col0, #T_0ab20_row1_col0, #T_0ab20_row2_col0, #T_0ab20_row3_col0, #T_0ab20_row4_col0, #T_0ab20_row5_col0, #T_0ab20_row6_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_0ab20_row0_col1, #T_0ab20_row1_col1, #T_0ab20_row2_col1, #T_0ab20_row3_col1, #T_0ab20_row4_col1, #T_0ab20_row5_col1, #T_0ab20_row6_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_0ab20_row0_col2, #T_0ab20_row2_col2 {
#   background-color: #7f7bb9;
#   color: #f1f1f1;
# }
# #T_0ab20_row1_col2 {
#   background-color: #8e8bc1;
#   color: #f1f1f1;
# }
# #T_0ab20_row3_col2 {
#   background-color: #8e8ac0;
#   color: #f1f1f1;
# }
# #T_0ab20_row4_col2 {
#   background-color: #807dba;
#   color: #f1f1f1;
# }
# #T_0ab20_row5_col2 {
#   background-color: #8986be;
#   color: #f1f1f1;
# }
# #T_0ab20_row6_col2 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0ab20">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Time</th>
#       <th id="T_0ab20_level0_col0" class="col_heading level0 col0" >EARLY</th>
#       <th id="T_0ab20_level0_col1" class="col_heading level0 col1" >LATE</th>
#       <th id="T_0ab20_level0_col2" class="col_heading level0 col2" >ON TIME</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >WEEKDAY</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ab20_level0_row0" class="row_heading level0 row0" >Friday</th>
#       <td id="T_0ab20_row0_col0" class="data row0 col0" >2.042509</td>
#       <td id="T_0ab20_row0_col1" class="data row0 col1" >-3.478286</td>
#       <td id="T_0ab20_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab20_level0_row1" class="row_heading level0 row1" >Monday</th>
#       <td id="T_0ab20_row1_col0" class="data row1 col0" >2.094735</td>
#       <td id="T_0ab20_row1_col1" class="data row1 col1" >-2.698897</td>
#       <td id="T_0ab20_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab20_level0_row2" class="row_heading level0 row2" >Saturday</th>
#       <td id="T_0ab20_row2_col0" class="data row2 col0" >2.224832</td>
#       <td id="T_0ab20_row2_col1" class="data row2 col1" >-3.828429</td>
#       <td id="T_0ab20_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab20_level0_row3" class="row_heading level0 row3" >Sunday</th>
#       <td id="T_0ab20_row3_col0" class="data row3 col0" >2.131061</td>
#       <td id="T_0ab20_row3_col1" class="data row3 col1" >-2.795303</td>
#       <td id="T_0ab20_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab20_level0_row4" class="row_heading level0 row4" >Thursday</th>
#       <td id="T_0ab20_row4_col0" class="data row4 col0" >2.006222</td>
#       <td id="T_0ab20_row4_col1" class="data row4 col1" >-3.297381</td>
#       <td id="T_0ab20_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab20_level0_row5" class="row_heading level0 row5" >Tuesday</th>
#       <td id="T_0ab20_row5_col0" class="data row5 col0" >1.977117</td>
#       <td id="T_0ab20_row5_col1" class="data row5 col1" >-2.841625</td>
#       <td id="T_0ab20_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab20_level0_row6" class="row_heading level0 row6" >Wednesday</th>
#       <td id="T_0ab20_row6_col0" class="data row6 col0" >2.073407</td>
#       <td id="T_0ab20_row6_col1" class="data row6 col1" >-2.899749</td>
#       <td id="T_0ab20_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
TIME_PERF = []

##loop to check adherence column to determine if early, late, or on time append

for x in headway_holiday['ADHERENCE']:
    if x > 0:
        TIME_PERF.append('EARLY')
    elif x < 0:
        TIME_PERF.append('LATE')
    else:
        TIME_PERF.append('ON TIME')

# %%
headway_holiday.shape
# Out:
# (48109, 23)

# %%
len(TIME_PERF)
# Out:
# 48109

# %%
headway_holiday['Time']  = TIME_PERF
# Out:
# C:\Users\cside\AppData\Local\Temp\ipykernel_11932\638297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headway_holiday['Time']  = TIME_PERF

# %%
headway_holiday.head(10)

# %%
(headway_holiday.pivot_table(
        index='WEEKDAY',
    columns= 'Time',
    values='ADHERENCE',
    aggfunc= 'mean').style.background_gradient(cmap='Purples', axis=1))
# Out:
# <style type="text/css">
# #T_ecb5a_row0_col0, #T_ecb5a_row1_col0, #T_ecb5a_row2_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_ecb5a_row0_col1, #T_ecb5a_row1_col1, #T_ecb5a_row2_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_ecb5a_row0_col2 {
#   background-color: #8582bc;
#   color: #f1f1f1;
# }
# #T_ecb5a_row1_col2 {
#   background-color: #8f8cc1;
#   color: #f1f1f1;
# }
# #T_ecb5a_row2_col2 {
#   background-color: #9591c4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ecb5a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Time</th>
#       <th id="T_ecb5a_level0_col0" class="col_heading level0 col0" >EARLY</th>
#       <th id="T_ecb5a_level0_col1" class="col_heading level0 col1" >LATE</th>
#       <th id="T_ecb5a_level0_col2" class="col_heading level0 col2" >ON TIME</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >WEEKDAY</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecb5a_level0_row0" class="row_heading level0 row0" >Friday</th>
#       <td id="T_ecb5a_row0_col0" class="data row0 col0" >1.868258</td>
#       <td id="T_ecb5a_row0_col1" class="data row0 col1" >-2.839899</td>
#       <td id="T_ecb5a_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ecb5a_level0_row1" class="row_heading level0 row1" >Monday</th>
#       <td id="T_ecb5a_row1_col0" class="data row1 col0" >2.049929</td>
#       <td id="T_ecb5a_row1_col1" class="data row1 col1" >-2.618830</td>
#       <td id="T_ecb5a_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ecb5a_level0_row2" class="row_heading level0 row2" >Thursday</th>
#       <td id="T_ecb5a_row2_col0" class="data row2 col0" >2.018207</td>
#       <td id="T_ecb5a_row2_col1" class="data row2 col1" >-2.356024</td>
#       <td id="T_ecb5a_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
