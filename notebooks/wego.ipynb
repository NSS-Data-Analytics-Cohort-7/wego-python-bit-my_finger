# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv("../data/bna_weather.csv", nrows=9740)

# %%
headway = pd.read_csv("../data/Headway_Data.csv", nrows=1981716)

# %% [markdown]
# pd.set_option allows you to see all columns   rest it pd.reset_option("max_columns")

# %%
pd.set_option('display.max_columns', None)

# %%
headway.head(10)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
# 5    120211101             1      76447969  2021-11-01          22
# 6    120211101             1      76447970  2021-11-01          22
# 7    120211101             1      76447971  2021-11-01          22
# 8    120211101             1      76447972  2021-11-01          22
# 9    120211101             1      76447973  2021-11-01          22
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# ...

# %%
headway.dtypes
# Out:
# CALENDAR_ID                    int64
# SERVICE_ABBR                   int64
# ADHERENCE_ID                   int64
# DATE                          object
# ROUTE_ABBR                     int64
# BLOCK_ABBR                     int64
# OPERATOR                       int64
# TRIP_ID                        int64
# OVERLOAD_ID                    int64
# ROUTE_DIRECTION_NAME          object
# TIME_POINT_ABBR               object
# ROUTE_STOP_SEQUENCE          float64
# TRIP_EDGE                      int64
# LATITUDE                     float64
# LONGITUDE                    float64
# SCHEDULED_TIME                object
# ACTUAL_ARRIVAL_TIME           object
# ACTUAL_DEPARTURE_TIME         object
# ADHERENCE                    float64
# SCHEDULED_HDWY               float64
# ACTUAL_HDWY                  float64
# HDWY_DEV                     float64
# ADJUSTED_EARLY_COUNT           int64
# ADJUSTED_LATE_COUNT            int64
# ADJUSTED_ONTIME_COUNT          int64
# ...

# %%
headway.shape
# Out:
# (1981715, 30)

# %%
weather.shape
# Out:
# (9739, 46)

# %%
weather.shape
# Out:
# (9739, 46)

# %%
weather.head(10)
# Out:
#                   Date   key        class  expire_time_gmt obs_id   obs_name  \
# 0  2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA  Nashville
# 1  2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA  Nashville
# 2  2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA  Nashville
# 3  2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA  Nashville
# 4  2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA  Nashville
# 5  2021-11-01 04:53:00  KBNA  observation       1635767580   KBNA  Nashville
# 6  2021-11-01 05:53:00  KBNA  observation       1635771180   KBNA  Nashville
# 7  2021-11-01 06:53:00  KBNA  observation       1635774780   KBNA  Nashville
# 8  2021-11-01 07:53:00  KBNA  observation       1635778380   KBNA  Nashville
# 9  2021-11-01 08:53:00  KBNA  observation       1635781980   KBNA  Nashville
#
#    valid_time_gmt day_ind  temp  wx_icon  icon_extd      wx_phrase  \
# ...

# %%
headway['ROUTE_ABBR'].value_counts()
# Out:
# 55    362259
# 56    355098
# 52    291150
# 23    250787
# 50    249880
# 3     216446
# 22    153074
# 7     103021
# Name: ROUTE_ABBR, dtype: int64

# %%
headway.drop(headway.columns[[-1,-2]], axis = 1, inplace=True)

# %%
headway.shape
# Out:
# (1981715, 28)

# %%
headway.head(10)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
# 5    120211101             1      76447969  2021-11-01          22
# 6    120211101             1      76447970  2021-11-01          22
# 7    120211101             1      76447971  2021-11-01          22
# 8    120211101             1      76447972  2021-11-01          22
# 9    120211101             1      76447973  2021-11-01          22
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# ...

# %%
headway.shape
# Out:
# (1981715, 28)

# %%
headway['TRIP_EDGE'].value_counts()
# Out:
# 0    1209965
# 2     387235
# 1     384515
# Name: TRIP_EDGE, dtype: int64

# %%
headway.head(10)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
# 5    120211101             1      76447969  2021-11-01          22
# 6    120211101             1      76447970  2021-11-01          22
# 7    120211101             1      76447971  2021-11-01          22
# 8    120211101             1      76447972  2021-11-01          22
# 9    120211101             1      76447973  2021-11-01          22
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# ...

# %%
headway['ROUTE_ABBR'].value_counts()
# Out:
# 55    362259
# 56    355098
# 52    291150
# 23    250787
# 50    249880
# 3     216446
# 22    153074
# 7     103021
# Name: ROUTE_ABBR, dtype: int64

# %%
headway['OPERATOR'].value_counts()
# Out:
# 1147    15479
# 1587    15352
# 664     15268
# 409     14889
# 1020    14495
#         ...
# 2091        1
# 2219        1
# 242         1
# 315         1
# 2310        1
# Name: OPERATOR, Length: 458, dtype: int64
