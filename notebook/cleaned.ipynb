# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.cm import PRGn
import seaborn as sns
import calendar
from datetime import date
from datetime import datetime
plt.style.use('ggplot')
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
headway = pd.read_csv("../data/Headway_data.csv", nrows=1981716)

# %%
pd.set_option('display.max_columns', None)

# %%
headway.head(4)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# 2        1704      2088   297750            0          TO DOWNTOWN
# 3        1704      2088   297749            0          TO DOWNTOWN
#
#   TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 0            HBHS                  4.0          1  36.107575 -86.812719
# 1            21BK                  3.0          0  36.138372 -86.800622
# 2          MCC5_9                  2.0          2  36.167091 -86.781923
# ...

# %%
headway.drop(headway.columns[[-1,-2, -3, -4, -5, -6, -7, -8]], axis = 1, inplace=True)

# %%
headway.head(3)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# 2        1704      2088   297750            0          TO DOWNTOWN
#
#   TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 0            HBHS                  4.0          1  36.107575 -86.812719
# 1            21BK                  3.0          0  36.138372 -86.800622
# 2          MCC5_9                  2.0          2  36.167091 -86.781923
#
#   SCHEDULED_TIME ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  \
# ...

# %%
headway['DATE'] =  pd.to_datetime(headway['DATE'])

# %%
headway['WEEKDAY'] = [calendar.day_name[x.weekday()] for x in headway['DATE']]
headway.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 headway['WEEKDAY'] = [calendar.day_name[x.weekday()] for x in headway['DATE']]
#       2 headway.head()
#
# Input In [22], in <listcomp>(.0)
# ----> 1 headway['WEEKDAY'] = [calendar.day_name[x.weekday()] for x in headway['DATE']]
#       2 headway.head()
#
# AttributeError: type object 'USFederalHolidayCalendar' has no attribute 'day_name'

# %%
DOW = headway[['WEEKDAY','SCHEDULED_HDWY', 'ACTUAL_HDWY','ADHERENCE', 'ROUTE_ABBR']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 DOW = headway[['WEEKDAY','SCHEDULED_HDWY', 'ACTUAL_HDWY','ADHERENCE', 'ROUTE_ABBR']]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
# ...

# %%
#| works as an or operator 
summer = headway[(headway["DATE"] >= '2022-06-01') & (headway["DATE"] <= '2022-08-01')]
#headway['DATE'] > '2022-06-01') & (headway['DATE'] <= '2022-08-01')])]

# %%
summer['DATE'].value_counts()
# Out:
# 2022-06-03    6451
# 2022-07-20    6441
# 2022-07-08    6438
# 2022-06-13    6431
# 2022-07-07    6428
#               ...
# 2022-06-05    3674
# 2022-06-12    3674
# 2022-07-03    3673
# 2022-07-04    3671
# 2022-06-19    3645
# Name: DATE, Length: 62, dtype: int64

# %% [markdown]
# RUSH_HOUR = []
#
# for x in hw_clean['SCHEDULED_TIME']: if x >= '07:00:00' and x <= '09:30:00': RUSH_HOUR.append('Morning Rush') elif x >= '16:00:00' and x <= '18:00:00': RUSH_HOUR.append('Evening Rush') else: RUSH_HOUR.append('No Rush') RUSH_HOUR

# %%
summer.head(10)
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  \
# 1109085    120220601             1      85713482 2022-06-01          22
# 1109086    120220601             1      85713483 2022-06-01          22
# 1109087    120220601             1      85713484 2022-06-01          22
# 1109088    120220601             1      85713485 2022-06-01          22
# 1109089    120220601             1      85713486 2022-06-01          22
# 1109090    120220601             1      85713487 2022-06-01          22
# 1109091    120220601             1      85713488 2022-06-01          22
# 1109092    120220601             1      85713489 2022-06-01          22
# 1109093    120220601             1      85713490 2022-06-01          22
# 1109094    120220601             1      85713491 2022-06-01          22
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 1109085        2200      1280   311622            0          TO DOWNTOWN
# ...
