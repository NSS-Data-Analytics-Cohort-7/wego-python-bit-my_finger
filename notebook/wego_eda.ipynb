# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv('../Data/bna_weather.csv')

# %%
weather.head()
# Out:
#                   Date   key        class  expire_time_gmt obs_id   obs_name  \
# 0  2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA  Nashville
# 1  2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA  Nashville
# 2  2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA  Nashville
# 3  2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA  Nashville
# 4  2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA  Nashville
#
#    valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# 0      1635745980       N    51       26  ...   OVC        NaN
# 1      1635748200       N    50       29  ...   SCT        NaN
# 2      1635749580       N    49       33  ...   CLR        NaN
# 3      1635753180       N    48       33  ...   CLR        NaN
# 4      1635756780       N    47       33  ...   CLR        NaN
#
#    primary_wave_period primary_wave_height  primary_swell_period  \
# ...

# %%
weather.info
# Out:
# <bound method DataFrame.info of                      Date   key        class  expire_time_gmt obs_id  \
# 0     2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA
# 1     2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA
# 2     2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA
# 3     2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA
# 4     2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA
# ...                   ...   ...          ...              ...    ...
# 9734  2022-10-31 19:53:00  KBNA  observation       1667271180   KBNA
# 9735  2022-10-31 20:53:00  KBNA  observation       1667274780   KBNA
# 9736  2022-10-31 21:53:00  KBNA  observation       1667278380   KBNA
# 9737  2022-10-31 22:53:00  KBNA  observation       1667281980   KBNA
# 9738  2022-10-31 23:53:00  KBNA  observation       1667285580   KBNA
#
#        obs_name  valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# ...

# %%
weather.isna().sum()
# Out:
# Date                            0
# key                             0
# class                           0
# expire_time_gmt                 0
# obs_id                          0
# obs_name                        0
# valid_time_gmt                  0
# day_ind                         0
# temp                            0
# wx_icon                         0
# icon_extd                       0
# wx_phrase                       0
# pressure_tend                6854
# pressure_desc                6854
# dewPt                           0
# heat_index                      0
# rh                              0
# pressure                        0
# vis                             4
# wc                              8
# wdir                         1522
# wdir_cardinal                   8
# gust                         8279
# wspd                            8
# max_temp                     9378
# min_temp                     9378
# precip_total                 9636
# ...

# %%
weather['Date'].value_counts()
# Out:
# 2021-11-07 01:53:00    2
# 2021-11-01 00:53:00    1
# 2022-06-29 10:53:00    1
# 2022-06-29 03:53:00    1
# 2022-06-29 04:53:00    1
#                       ..
# 2022-02-25 07:53:00    1
# 2022-02-25 08:13:00    1
# 2022-02-25 08:53:00    1
# 2022-02-25 09:53:00    1
# 2022-10-31 23:53:00    1
# Name: Date, Length: 9738, dtype: int64

# %%
headway = pd.read_csv('../Data/Headway Data.csv.txt')

# %%
headway.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# 0        1704      2088   297750            0          TO DOWNTOWN  ...
# 1        1704      2088   297750            0          TO DOWNTOWN  ...
# 2        1704      2088   297750            0          TO DOWNTOWN  ...
# 3        1704      2088   297749            0          TO DOWNTOWN  ...
# 4        1704      2088   297749            0          TO DOWNTOWN  ...
#
#   ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
print(headway)
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 2          120211101             1      76447166  2021-11-01           7
# 3          120211101             1      76447167  2021-11-01          50
# 4          120211101             1      76447168  2021-11-01          50
# ...              ...           ...           ...         ...         ...
# 1981710    120221101             1      91057724  2022-11-01          50
# 1981711    120221101             1      91057851  2022-11-01          50
# 1981712    120221101             1      91057852  2022-11-01          50
# 1981713    120221101             1      91057881  2022-11-01          56
# 1981714    120221101             1      91057882  2022-11-01          56
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# ...

# %%
headway['OPERATOR'].value_counts(dropna = False)
# Out:
# 1147    15479
# 1587    15352
# 664     15268
# 409     14889
# 1020    14495
#         ...
# 2091        1
# 2219        1
# 242         1
# 315         1
# 2310        1
# Name: OPERATOR, Length: 458, dtype: int64

# %%
headway['OPERATOR'].value_counts(normalize = True)
# Out:
# 1147    7.810911e-03
# 1587    7.746825e-03
# 664     7.704438e-03
# 409     7.513189e-03
# 1020    7.314372e-03
#             ...
# 2091    5.046134e-07
# 2219    5.046134e-07
# 242     5.046134e-07
# 315     5.046134e-07
# 2310    5.046134e-07
# Name: OPERATOR, Length: 458, dtype: float64

# %%
headway['OPERATOR'].value_counts().plot(kind = 'bar');

# %%
headway.tail()
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 1981710    120221101             1      91057724  2022-11-01          50
# 1981711    120221101             1      91057851  2022-11-01          50
# 1981712    120221101             1      91057852  2022-11-01          50
# 1981713    120221101             1      91057881  2022-11-01          56
# 1981714    120221101             1      91057882  2022-11-01          56
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 1981710        9302      2355   329980            0          TO DOWNTOWN
# 1981711        9950      1880   330003            0          TO DOWNTOWN
# 1981712        9950      1880   330003            0          TO DOWNTOWN
# 1981713        9975      1922   330011            0          TO DOWNTOWN
# 1981714        9975      1922   330011            0          TO DOWNTOWN
#
#         TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
headway.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# 0        1704      2088   297750            0          TO DOWNTOWN
# 1        1704      2088   297750            0          TO DOWNTOWN
# 2        1704      2088   297750            0          TO DOWNTOWN
# 3        1704      2088   297749            0          TO DOWNTOWN
# 4        1704      2088   297749            0          TO DOWNTOWN
#
#   TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE   LATITUDE  LONGITUDE  \
# 0            HBHS                  4.0          1  36.107575 -86.812719
# ...

# %%
route55 = headway.loc[headway['ROUTE_ABBR']==55]

# %%
route55 = route55.loc[route55['DATE'] == '2021-11-01']
route55 = route55.loc[route55['OPERATOR'] == 1716]
route55
# Out:
#       CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 3320    120211101             1      76452743  2021-11-01          55
# 3321    120211101             1      76452744  2021-11-01          55
# 3322    120211101             1      76452745  2021-11-01          55
# 3323    120211101             1      76452746  2021-11-01          55
# 3324    120211101             1      76452747  2021-11-01          55
# ...           ...           ...           ...         ...         ...
# 3381    120211101             1      76452804  2021-11-01          55
# 3382    120211101             1      76452805  2021-11-01          55
# 3383    120211101             1      76452806  2021-11-01          55
# 3384    120211101             1      76452807  2021-11-01          55
# 3385    120211101             1      76452808  2021-11-01          55
#
#       BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# ...

# %%
print(route55)
# Out:
#       CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 3320    120211101             1      76452743  2021-11-01          55
# 3321    120211101             1      76452744  2021-11-01          55
# 3322    120211101             1      76452745  2021-11-01          55
# 3323    120211101             1      76452746  2021-11-01          55
# 3324    120211101             1      76452747  2021-11-01          55
# ...           ...           ...           ...         ...         ...
# 3381    120211101             1      76452804  2021-11-01          55
# 3382    120211101             1      76452805  2021-11-01          55
# 3383    120211101             1      76452806  2021-11-01          55
# 3384    120211101             1      76452807  2021-11-01          55
# 3385    120211101             1      76452808  2021-11-01          55
#
#       BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# ...

# %%
route55
# Out:
#       CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 3320    120211101             1      76452743  2021-11-01          55
# 3321    120211101             1      76452744  2021-11-01          55
# 3322    120211101             1      76452745  2021-11-01          55
# 3323    120211101             1      76452746  2021-11-01          55
# 3324    120211101             1      76452747  2021-11-01          55
# ...           ...           ...           ...         ...         ...
# 3381    120211101             1      76452804  2021-11-01          55
# 3382    120211101             1      76452805  2021-11-01          55
# 3383    120211101             1      76452806  2021-11-01          55
# 3384    120211101             1      76452807  2021-11-01          55
# 3385    120211101             1      76452808  2021-11-01          55
#
#       BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  \
# ...

# %%
..
